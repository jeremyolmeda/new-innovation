# %% [markdown]
# # Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %% [markdown]
# The history of python
#
# python began to be used in 1989 when Guido Van Rossum decided to start the project as a hobby giving continuity to the ABC programming language of which he had been part of the development team at the CWI, The Python programming language was originally developed for the system Amoeba operative.

# %% [markdown]
# As we can see in the following images we can see how the python versions progressed.
# ![PythonTimeline_1.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are codes that can be very simple. An example would be
#
#  print ("hello")
#
# this command will be in charge of sending the content that is in the parenthesis "hello"
#
# another command would be to declare a variable.
# this can be called in any way for example
#
# sum = 10
#
# in that part they declare the variable sum and at the same time we are giving it the value of 10
#
# This command and variable can be used to form a new command and it will include the variable that is declared before using the print command. Example:
#
# name = "jeremy"
#
# age = 19
#
# print ("hello", name, "you have", age, "years")
#
# hello jeremy you have 19 years

# %%
name = "jeremy"

age = 19

print ("hello", name, "you have", age, "years")
# Out:
# hello jeremy you have 19 years

# %% [markdown]
# and also in that intante data can be saved by adding the input command implying that a data is going to be saved in that variable

# %%
name = input("Dijite su nombre: ")

print(f"Hello {name}")
# Out:
# Dijite su nombre: jeremy
# Hello jeremy

# %% [markdown]
# In case you want to use number, it would be depending on the number since a different command is used depending on the time of the number, which is either an integer or not an integer, for the integer int (input ("...")) is used but for in non-integer the float would be used (input ("...")) that type has to be used for each type, in the event that this type is not used, it would mark an error because it is not made for that type

# %%
number = int(input("digitar un numero entero:"))
name = float(input("digitar un numero no entero"))
# Out:
# digitar un numero entero:2
# digitar un numero no entero2.2

# %% [markdown]
# Also in python you can use command to do mathematical operations, be it addition, subtraction, multiplication and division.
# that depends on what you want to do, the command would be

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A command that can be useful is the if else, this command asks us to fulfill the condition that it asks us depending on the case, as in the following case

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Text cells
# This is a **text cell**. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).
#
# You can also add math to text cells using [LaTeX](http://www.latex-project.org/)
# to be rendered by [MathJax](https://www.mathjax.org). Just place the statement
# within a pair of **\$** signs. For example `$\sqrt{3x-1}+(1+x)^2$` becomes
# $\sqrt{3x-1}+(1+x)^2.$
